# %%
#accessing custom data set

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Define paths to your data directories
train_data_dir = r"C:\Users\abhis\Desktop\Dataset Text\Blur"
validation_data_dir = r"C:\Users\abhis\Desktop\Dataset Text\Sharp"

# Set up data generators
train_datagen = ImageDataGenerator(rescale=1./255)  # Normalize pixel values
validation_datagen = ImageDataGenerator(rescale=1./255)

# Load data using flow_from_directory
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(224, 224),  # Adjust image size as needed
    batch_size=32,
    class_mode='categorical'  # Adjust for your classification type
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 185 images belonging to 1 classes.
# Found 185 images belonging to 1 classes.

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# ... (rest of your code defining data paths and generators)
# Define paths to your data directories
train_data_dir = r"C:\Users\abhis\Desktop\Dataset Text\Blur"
validation_data_dir = r"C:\Users\abhis\Desktop\Dataset Text\Sharp"

# Set up data generators
train_datagen = ImageDataGenerator(rescale=1./255)  # Normalize pixel values
validation_datagen = ImageDataGenerator(rescale=1./255)

# Load data using flow_from_directory
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(224, 224),  # Adjust image size as needed
    batch_size=32,
    class_mode='categorical'  # Adjust for your classification type
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='categorical'
)

# Preview a sample of training data
def visualize_data(generator):
  # Get a batch of samples
  X_batch, y_batch = next(generator)

  # Plot some images (adjust number of images as desired)
  plt.figure(figsize=(10, 5))
  for i in range(5):
    plt.subplot(2, 3, i+1)
    plt.imshow(X_batch[i], cmap='gray_r')
    plt.title(f"Class: {y_batch[i]}")
    plt.axis('off')
  plt.show()

# Preview some training data
visualize_data(train_generator)

# Preview some validation data (optional)
visualize_data(validation_generator)
# Out:
# Found 185 images belonging to 1 classes.
# Found 185 images belonging to 1 classes.

# %%
import os  # For checking directory contents (optional)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Define paths to your data directories (replace with actual paths)
train_data_dir = r"C:\Users\abhis\Desktop\Dataset Text\Blur"
validation_data_dir = r"C:\Users\abhis\Desktop\Dataset Text\Sharp"

# Set up data generators
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

def check_data(data_dir):
  # Optionally check the number of images in directories
  num_images = len(os.listdir(data_dir))
  if num_images > 0:
    print(f"Found {num_images} images in {data_dir}")
    return True
  else:
    print(f"No images found in {data_dir}")
    return False

# Check training and validation data directories (optional)
if not check_data(train_data_dir) or not check_data(validation_data_dir):
  exit()  # Exit if no images found in directories

# Load data using flow_from_directory (assuming no classes)
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(224, 224),
    batch_size=32,
    class_mode='binary'  # Assuming binary classification
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(224, 224),  
    batch_size=32,
    class_mode='binary'  # Assuming binary classification
)

# Preview a sample of training data (assuming binary classification)
def visualize_data(generator):
  # Get a batch of samples
  X_batch, y_batch = next(generator)

  # Plot some images
  plt.figure(figsize=(10, 5))
  for i in range(5):
    plt.subplot(2, 3, i+1)
    plt.imshow(X_batch[i], cmap='gray_r')
    plt.title(f"Label: {y_batch[i]}")  # Assuming binary classification
    plt.axis('off')
  plt.show()

# Preview some training data
visualize_data(train_generator)

# Preview some validation data (optional)
visualize_data(validation_generator)
# Out:
# Found 1 images in C:\Users\abhis\Desktop\Dataset Text\Blur
# Found 1 images in C:\Users\abhis\Desktop\Dataset Text\Sharp
# Found 185 images belonging to 1 classes.
# Found 185 images belonging to 1 classes.

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Define data paths and image size
data_dir = {
    "blur": r"C:\Users\abhis\Desktop\Dataset Text\Blur",  # Path to blurry images
    "sharp": r"C:\Users\abhis\Desktop\Dataset Text\Sharp"   # Path to sharp images
}

img_width, img_height = 28, 28  # Assuming your images are 28x28 (adjust if needed)

# Print directory contents
print("Contents of Blur directory:")
print(os.listdir(data_dir["blur"]))  # List files in "Blur" directory

print("Contents of Sharp directory:")
print(os.listdir(data_dir["sharp"]))  # List files in "Sharp" directory

# Load data with error handling
try:
  # Define data generators
  train_datagen = ImageDataGenerator(rescale=1./255)  # Normalize pixel values

  blur_generator = train_datagen.flow_from_directory(
      data_dir["blur"],
      target_size=(img_width, img_height),
      batch_size=32,
      class_mode='binary'  # Assuming blurry/sharp is a binary classification
  )

  sharp_generator = train_datagen.flow_from_directory(
      data_dir["sharp"],
      target_size=(img_width, img_height),
      batch_size=32,
      class_mode='binary'
  )

  # ... rest of your code for data loading and visualization (if needed)

except OSError as e:
  print("Error loading data:", e)
# Out:
# WARNING:tensorflow:From C:\Users\abhis\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# Contents of Blur directory:
# ['data']
# Contents of Sharp directory:
# ['data']
# Found 185 images belonging to 1 classes.
# Found 185 images belonging to 1 classes.
